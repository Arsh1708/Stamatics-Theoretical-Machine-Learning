# %%
import random
import numpy as np
import matplotlib.pyplot as plt

# %%
N=50
X = [random.uniform(0, 10) for i in range(N)]
X=np.array(X)

# %%
Y=[]
for i in x:
    Y.append(3*i+5+random.uniform(0, 2))
Y=np.array(Y)

# %%
m = (N*sum(X*Y) - sum(X) * sum(Y))/(N * sum(X**2) - (sum(X))**2)
c = (sum(Y) * sum(X**2) - sum(X) * sum(X*Y))/(N * sum(X**2) - (sum(X))**2)

# %%
plt.scatter(X, Y)
X_1 = np.min(X)
Y_1 = m * X_1 + c
X_2 = np.max(X)
Y_2 = m * X_2 + c
plt.plot([X_1, X_2], [Y_1, Y_2], color = "black")
plt.show()
